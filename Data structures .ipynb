# %%
#PURUSHOTHAM GS

# %%
a=23
print(type(a))
# Out:
# <class 'int'>

# %%
a=45.87
print(type(a))
# Out:
# <class 'float'>

# %%
a="deekshith"
print(type(a))
# Out:
# <class 'str'>

# %%
a=[10.24,67]
print(type(a))
print(a)
# Out:
# <class 'list'>
# [10.24, 67]

# %%
a=(23,"the")
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (23, 'the')

# %%
a={13,"puru"}
print(type(a))
print(a)
# Out:
# <class 'set'>
# {13, 'puru'}

# %%
a=52
print("value of a is",a)
print(type(a))
# Out:
# value of a is 52
# <class 'int'>

# %%
a={1:2}
print(type(a))
print(a)
# Out:
# <class 'dict'>
# {1: 2}

# %%
a=43
b=83
print("value of a and b are",a,b)
# Out:
# value of a and b are 43 83

# %%
a=37
b=82
print("values of a and b are {} and {}".format(a,b))
print("values of a and b are {0} and {1}".format(a,b))
print("values of b and a are {1} and {0}".format(a,b))
# Out:
# values of a and b are 37 and 82
# values of a and b are 37 and 82
# values of b and a are 82 and 37

# %%
print("Purushotham hates {2}, but loves {0} and {1}".format ("chatting","eating","himself"))
# Out:
# Purushotham hates himself, but loves chatting and eating

# %%
print("Today {2} is wearing black derss to \
 to impress {3} in {1} class,but {0} liked him." \
      .format("putti","AIML","Pavan","PJ"))
# Out:
# Today Pavan is wearing black derss to  to impress PJ in AIML class,but putti liked him.

# %%
a=input("enter a number ")
print(a)
print(type(a))
# Out:
# enter a number as
# as
# <class 'str'>

# %%
a=int(input("enter a number "))
print(a)
print(type(a))
# Out:
# enter a number 5
# 5
# <class 'int'>

# %%
a=int(input("enter the 1st number "))
b=int(input("enter the second number "))
print("Product of two numbers is {}". format(a*b))
# Out:
# enter the 1st number 3
# enter the second number 8
# Product of two numbers is 24

# %%
a=input("Enter your name ")
b=int(input("Enter your age "))
print("Your name is {} and your age after 10 years is {}". format (a,b+10))
# Out:
# Enter your name Mr.Computer
# Enter your age 23
# Your name is Mr.Computer and your age after 10 years is 33

# %% [markdown]
# Date: 26.12.25

# %% [markdown]
# Test 1

# %%
a=int(input("Enter a number"))
if a%5==0 and a%7==0:
  print("Number {} is divisible by 5 and 7".format(a))
else:
  print("Number {} is not divisible by 5 and 7".format(a))
# Out:
# Enter a number57
# Number 57 is not divisible by 5 and 7

# %%
r=int(input("enter the radius "))
a=int(input("enter 1 for area or 2 for perimeter "))
if a==1:
    print("Area of circle is {}".format(3.14*r**2))
elif a==2:
    print("Perimeter of circle is {}".format(2*3.14*r))
else:
  print("invalid input")
# Out:
# enter the radius 1
# enter 1 for area or 2 for perimeter 1
# Area of circle is 3.14

# %%
n1=int(input("enter 1st number "))
n2=int(input('enter 2nd number '))
if n1>n2:
  print("{} is greater".format(n1))
elif n2>n1:
  print("{} is greater ".format(n2))
else:
  print("both are equal")
# Out:
# enter 1st number 67
# enter 2nd number 675
# 675 is greater

# %% [markdown]
# class
# Topic - List

# %%
list1=[1,4,'hello'] #heterogenous elements
print(list1)
print(len(list1))t
# Out:
# [1, 4, 'hello']
# 3
# 0

# %%
print(list1.index(1))
# Out:
# 0

# %%
list1.append('hi')
print(list1)
# Out:
# [1, 4, 'hello', 'hi', 'hi', 'hi']

# %%
print(list1.count('hi'))
# Out:
# 3

# %%
list1.insert(3,'bye') #insert(index,value)
print(list1)
# Out:
# [1, 4, 'hello', 'bye', 'hi', 'hi', 'hi']

# %%
list1.reverse()
print(list1)
# Out:
# ['hi', 'hi', 'hi', 'bye', 'hello', 4, 1]

# %%
list1.reverse()
print(list1)
# Out:
# [1, 4, 'hello', 'bye', 'hi', 'hi', 'hi']

# %%
print(list1.pop()) #last element will be removed,returns that value
print(list1) #print values of the list after pop
# Out:
# hi
# [1, 4, 'hello', 'bye', 'hi', 'hi']

# %%
print(list1.pop(4))
print(list1)
# Out:
# hi
# [1, 4, 'hello', 'bye', 'hi']

# %%
list1.clear() #removes all elementsand empty list will be there
print(list1)
# Out:
# []

# %%
list1=[2,45,78]
del(list1)
print(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2145760446.py in <cell line: 0>()
#       1 list1=[2,45,78]
#       2 del(list1)
# ----> 3 print(list1)
#
# NameError: name 'list1' is not defined

# %%
list1=[23,76,10]
print(list1)
list1.sort()
print(list1)
# Out:
# [23, 76, 10]
# [10, 23, 76]

# %%
print(max(list1))
# Out:
# 76

# %%
print(min(list1))
# Out:
# 10

# %%
l2=['a','t','G']
l2.sort()
print(l2)
# Out:
# ['G', 'a', 't']

# %%
l3=['pavan','pavan.m','Pavan'] #ASCII values
l3.sort()
print(l3)
# Out:
# ['Pavan', 'pavan', 'pavan.m']

# %%
a=[34,7,83]
b=a
print('a',a)
print('b',b)
b.insert(2,100)
print('a',a)
print('b',b)
# Out:
# a [34, 7, 83]
# b [34, 7, 83]
# a [34, 7, 100, 83]
# b [34, 7, 100, 83]

# %%
a=[34,7,83]
b=a.copy()
print('a',a)
print('b',b)
b.insert(2,100)
print('a',a)
print('b',b)
# Out:
# a [34, 7, 83]
# b [34, 7, 83]
# a [34, 7, 83]
# b [34, 7, 100, 83]
