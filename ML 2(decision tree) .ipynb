# %%
#PURUSHOTHAM GS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("iris.csv")

# %%
print(data)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data["Species"].value_counts()
#gives count of each unique value
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
data["Species"].unique()
#gives unique value
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,4]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(max_depth=None, min_samples_split=5,min_samples_leaf=2)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=2, min_samples_split=5)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
# ...

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.94

# %%
from sklearn.metrics import confusion_matrix
c=confusion_matrix(y_test,y_pred)
c
# Out:
# array([[16,  0,  0],
#        [ 0, 18,  1],
#        [ 0,  2, 13]])

# %%
from sklearn.metrics import classification_report as cr
print(cr(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.90      0.95      0.92        19
#  Iris-virginica       0.93      0.87      0.90        15
#
#        accuracy                           0.94        50
#       macro avg       0.94      0.94      0.94        50
#    weighted avg       0.94      0.94      0.94        50

# %%
from sklearn import tree
fn=["sepal length(cm)","sepal width(cm)","petal length(cm)","petal width(cm)"]
cn=["setosa","versicolor","virginica"]
fig, axes=plt.subplots(nrows=1,ncols=1, figsize=(4,4), dpi=300)
tree.plot_tree(model,
               feature_names=fn,
               class_names=cn,
               filled=True  )
# Out:
# [Text(0.4444444444444444, 0.9, 'petal length(cm) <= 2.35\ngini = 0.666\nsamples = 100\nvalue = [34, 31, 35]\nclass = virginica'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]\nclass = setosa'),
#  Text(0.38888888888888884, 0.8, 'True  '),
#  Text(0.5555555555555556, 0.7, 'petal width(cm) <= 1.75\ngini = 0.498\nsamples = 66\nvalue = [0, 31, 35]\nclass = virginica'),
#  Text(0.5, 0.8, '  False'),
#  Text(0.3333333333333333, 0.5, 'petal length(cm) <= 5.05\ngini = 0.165\nsamples = 33\nvalue = [0, 30, 3]\nclass = versicolor'),
#  Text(0.2222222222222222, 0.3, 'sepal length(cm) <= 5.0\ngini = 0.062\nsamples = 31\nvalue = [0, 30, 1]\nclass = versicolor'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 29\nvalue = [0, 29, 0]\nclass = versicolor'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
# ...

# %%
data['Species'].unique() #Gives the unique values in the column
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#Split the dataset into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
#Create decision tree classifier object
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy',max_depth=None,min_samples_split=5,min_samples_leaf=1) #These are Hyperparameters,Help in improve the Accuracy

# %%
#Train model(Fit Method)
model.fit(x_train,y_train)
print(model)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=5)

# %%
#Predict the testing model
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-setosa' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-virginica']

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[16  0  0]
#  [ 0 18  1]
#  [ 0  2 13]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.94

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.90      0.95      0.92        19
#  Iris-virginica       0.93      0.87      0.90        15
#
#        accuracy                           0.94        50
#       macro avg       0.94      0.94      0.94        50
#    weighted avg       0.94      0.94      0.94        50

# %%
from sklearn import tree
fn=['sepa length(cm)','sepal width(cm)','petal width(cm)','petal length(cm)']
cn=['setosa','versicolor','virginica']
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(4,4),dpi=300)
tree.plot_tree(model,
              feature_names=fn,
              class_names=cn,
              filled=True);
