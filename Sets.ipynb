# %%
#PURUSHOTHAM GS

# %%
i=1
while(i<=20):
    if i%3==0:
        print(i)
    i+=1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
i=1
while i<=10:
  if i==6:
    i+=1
  continue
  i+=1
  print(i)

# %%
S = {'E','A', 'B', 'E', 'F','E', 'F'}
print ("S                  -->", S)
print ("Number of elements -->", len(S))
print ("Type of Object     -->", type(S))
# Out:
# S                  --> {'B', 'E', 'A', 'F'}
# Number of elements --> 4
# Type of Object     --> <class 'set'>

# %%
S = set(['A', 'B', 'E', 'F','E', 'F' ])
print ("S                  -->", S)
print ("Number of elements -->", len(S))
print ("Type of Object     -->", type(S))
# Out:
# S                  --> {'F', 'E', 'A', 'B'}
# Number of elements --> 4
# Type of Object     --> <class 'set'>

# %%
S = {'A', 'B', 'E', 'F','E', 'F'}
print ("S -->", S)
print ("")
for i in S:
    print (i)
# Out:
# S --> {'B', 'E', 'A', 'F'}
#
# B
# E
# A
# F

# %%
S = {'A', 'B', 'E', 'F','E', 'F'}
print ("S -->", S)
print (S[2])
# Out:
# S --> {'B', 'E', 'A', 'F'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3624374794.py in <cell line: 0>()
#       1 S = {'A', 'B', 'E', 'F','E', 'F'}
#       2 print ("S -->", S)
# ----> 3 print (S[2])
#
# TypeError: 'set' object is not subscriptable

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S                -->", S)

S.add("D")
print ("After Adding (D) -->", S)
S.add("D")
print ("After Adding (D) -->", S)    # No Change in Set
S.add("C")
print ("After Adding (C) -->", S)
# Out:
# S                --> {'F', 'E', 'A', 'B'}
# After Adding (D) --> {'B', 'E', 'F', 'D', 'A'}
# After Adding (D) --> {'B', 'E', 'F', 'D', 'A'}
# After Adding (C) --> {'B', 'C', 'E', 'F', 'D', 'A'}

# %%
# Adding element to Set using update()
# Once a set is created, we cannot change the items, but we can add new items.
#Example 1:
S1 = set(['A', 'B', 'E', 'F' ])
S2 = set(["D", "E", "F", "G" ])
print ("S1              -->", S1)
print ("S2              -->", S2)
S1.update(S2)                       #inserts the items in S2 into S1; Union
# Out:
# S1              --> {'F', 'E', 'A', 'B'}
# S2              --> {'D', 'G', 'E', 'F'}

# %%
#Example 2:
S = set(['A', 'B', 'E', 'F' ])
print ("S              -->", S)
S.update(["F", "G", "H", "I"])
print ("After update S -->", S)
# Out:
# S              --> {'F', 'E', 'A', 'B'}
# After update S --> {'G', 'B', 'H', 'I', 'E', 'F', 'A'}

# %%
#Removing element from Set using remove()
S = set(['A', 'B', 'E', 'F' ])
print ("S                  -->", S)

S.remove("B")
print ("After removing (B) -->", S)

S.remove("E")
print ("After removing (E) -->", S)

S.remove("E")                           # Error
print ("After Adding (E) -->", S)

#Note: If the item does not exist, remove() will raise an exception
# Out:
# S                  --> {'F', 'E', 'A', 'B'}
# After removing (B) --> {'F', 'E', 'A'}
# After removing (E) --> {'F', 'A'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3065224471.py in <cell line: 0>()
#       9 print ("After removing (E) -->", S)
#      10
# ---> 11 S.remove("E")                           # Error
#      12 print ("After Adding (E) -->", S)
#      13
#
# KeyError: 'E'

# %%
#Removing element from Set using discard()

S = set(['A', 'B', 'E', 'F' ])
print ("S                 -->", S)

S.discard("B")
print ("After discard (B) -->", S)

S.discard("E")
print ("After discard (E) -->", S)

S.discard("E")                         # No Error
print ("After discard (E) -->", S)

#Note: If the item does not exist, discard() will NOT raise an exception
# Out:
# S                 --> {'F', 'E', 'A', 'B'}
# After discard (B) --> {'F', 'E', 'A'}
# After discard (E) --> {'F', 'A'}
# After discard (E) --> {'F', 'A'}

# %%
 # Removing element from Set using pop()
S = set(['A', 'B' ])
print ("S         -->", S)

S.pop()
print ("After pop -->", S)

S.pop()
print ("After pop -->", S)

S.pop()                       # Error; Set is empty; Under flow
print ("After pop -->", S)

#Note: If set is empty, pop() will raise an exception
# Out:
# S         --> {'A', 'B'}
# After pop --> {'B'}
# After pop --> set()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3394439544.py in <cell line: 0>()
#       9 print ("After pop -->", S)
#      10
# ---> 11 S.pop()                       # Error; Set is empty; Under flow
#      12 print ("After pop -->", S)
#      13
#
# KeyError: 'pop from an empty set'

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S               -->", S)

S.clear()            # Deleting all elements
print ("Set after clear -->", S)
# Out:
# S               --> {'F', 'E', 'A', 'B'}
# Set after clear --> set()

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S               -->", S)

del S
print ("Set after delete -->", S)   # Error
                                     # Set is deleted and still want to print
                                     # Exception should me handle
# Out:
# S               --> {'F', 'E', 'A', 'B'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1568438809.py in <cell line: 0>()
#       3
#       4 del S
# ----> 5 print ("Set after delete -->", S)   # Error
#       6                                      # Set is deleted and still want to print
#       7                                      # Exception should me handle
#
# NameError: name 'S' is not defined

# %%
S = {1, 3, 5, 6, 8, 9}
print ("S       -->", S)
print ("Sum     -->", sum(S))
print ("Average -->", sum(S)/len(S))
print ("Average -->", sum(S)//len(S))
print ("Max -->", max(S))
print ("Min -->", min(S))
# Out:
# S       --> {1, 3, 5, 6, 8, 9}
# Sum     --> 32
# Average --> 5.333333333333333
# Average --> 5
# Max --> 9
# Min --> 1

# %%
S = {1, 3, 5, 6, 8, 9}
print ("S            --> ", S)
print ("Is 2 Present -->", 2 in S)
print ("Is 9 Present -->", 9 in S)
# Out:
# S            -->  {1, 3, 5, 6, 8, 9}
# Is 2 Present --> False
# Is 9 Present --> True

# %%
thisset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)
# Out:
# cherry
# banana
# apple

# %%
a = {'A', 'B', 'E', 'F'}
b = set(["A", "C", "D", "E"])
print ("Set a -->", a)
print ("Set b -->", b)
# Out:
# Set a --> {'B', 'E', 'A', 'F'}
# Set b --> {'D', 'E', 'A', 'C'}

# %%
print ("Union of a and b          -->", a.union(b))    #ABEFCD
# Out:
# Union of a and b          --> {'B', 'C', 'E', 'F', 'D', 'A'}

# %%
print ("Intersection of a and b   -->", a.intersection(b))  #AE
# Out:
# Intersection of a and b   --> {'E', 'A'}

# %%
print ("Difference a - b          -->", a - b)
# Out:
# Difference a - b          --> {'F', 'B'}

# %%
print ("Difference a - b          -->", a.difference(b))    #BF
# Out:
# Difference a - b          --> {'F', 'B'}

# %%
print ("Difference b - a          -->", b - a)
# Out:
# Difference b - a          --> {'D', 'C'}

# %%
print ("Difference b - a          -->", b.difference(a))     #CD
# Out:
# Difference b - a          --> {'D', 'C'}

# %%
a = {'A', 'B', 'E', 'F'}
b = set(["A", "C", "D", "E"])
print ("Symetric Difference a - b -->", a.symmetric_difference(b))
print ("Symetric Difference b - a -->", b.symmetric_difference(a))
# Out:
# Symetric Difference a - b --> {'F', 'C', 'B', 'D'}
# Symetric Difference b - a --> {'F', 'C', 'B', 'D'}
