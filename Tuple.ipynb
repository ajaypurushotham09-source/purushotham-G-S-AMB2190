# %% [markdown]
# PURUSHOTHAM GS

# %%
x=(9,7,'deekshith','Purushotham')
print(type(x))
print(len(x))
print(x[2])
print(x[-1])
print(x[1:3])
# Out:
# <class 'tuple'>
# 4
# deekshith
# Purushotham
# (7, 'deekshith')

# %%
x=('KN',)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x=('KN')
print(type(x)) #Shows Strings
# Out:
# <class 'str'>

# %%
T=('Nikil','Deekshith',3,14,3)
i=0
while i<len(T):
  print(T[i])
  i+=1
# Out:
# Nikil
# Deekshith
# 3
# 14
# 3

# %%
t=(3,6,9,15,5,3,2)
print("T ",t)
print("T[2] ",t[2])
print("T[-3]",t[-3])
# Out:
# T  (3, 6, 9, 15, 5, 3, 2)
# T[2]  9
# T[-3] 5

# %%
T=(1,2,3,4,5,6)
print(T[1])
print(T[2])
print(T[-3])
print(T[1:4])
print(T[-1:-3])
print(T[1:4:2])
print(T[:-1])
print(T[-1:-4])
print(T[-4:-1])
# Out:
# 2
# 3
# 4
# (2, 3, 4)
# ()
# (2, 4)
# (1, 2, 3, 4, 5)
# ()
# (3, 4, 5)

# %%
T=(1,2,3,4,5,6)
T[2]=40
print(T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12140/1727529742.py in <cell line: 0>()
#       1 T=(1,2,3,4,5,6)
# ----> 2 T[2]=40
#       3 print(T)
#
# TypeError: 'tuple' object does not support item assignment

# %%
T=(1,2,3,4,5,6)
T.append(9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12140/476397350.py in <cell line: 0>()
#       1 T=(1,2,3,4,5,6)
# ----> 2 T.append(9)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
T=(1,2,3,4,5,6)
T.insert(2,"Rahul")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12140/2421744697.py in <cell line: 0>()
#       1 T=(1,2,3,4,5,6)
# ----> 2 T.insert(2,"Rahul")
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
T=(1,2,3,4,5,6)
print(T[::1])
print(T[::-1])
print(T[::-2])
print(T[::2])
print(T[:4:2])
# Out:
# (1, 2, 3, 4, 5, 6)
# (6, 5, 4, 3, 2, 1)
# (6, 4, 2)
# (1, 3, 5)
# (1, 3)

# %%
t=("ram",56,89,7)
t[1]=89
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-232100472.py in <cell line: 0>()
#       1 t=("ram",56,89,7)
# ----> 2 t[1]=89
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
T=(1,2,3,4,5,6)
X=list(T)
print(X)
X.append(8)
print(X)
print(tuple(X))
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 8]
# (1, 2, 3, 4, 5, 6, 8)

# %%
T=(1,2,3,4,5,6)
print('Sum is: ' ,sum(T))
print('Average is:',sum(T)/len(T))
print('Average is: ',sum(T)//len(T))
# Out:
# Sum is:  21
# Average is: 3.5
# Average is:  3

# %%
T=(1,2,3,4,5,6)
X=list(T)
print(X)
del X[2]
print(X)
print(tuple(X))
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 4, 5, 6]
# (1, 2, 4, 5, 6)

# %%
print('min: ',min(T))
print('max: ',max(T))
print(9 in T)
# Out:
# min:  1
# max:  6
# False

# %%
T=(1,2,3,4,5,6)
Y=(2,6,7,8,9,10)
Z=T+Y+Y
print(Z)
# Out:
# (1, 2, 3, 4, 5, 6, 2, 6, 7, 8, 9, 10, 2, 6, 7, 8, 9, 10)

# %%
T=(1,2,3,4,5,6)
Y=(2,6,7,8,9,10)
Z=T[:2]+Y[:4]
print(Z)
A=T[-2]+T[-3]
print(A)
# Out:
# (1, 2, 2, 6, 7, 8)
# 9

# %%
T=(1,2,3,4,5,6)
T.index(9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12140/2764821891.py in <cell line: 0>()
#       1 T=(1,2,3,4,5,6)
# ----> 2 T.index(9)
#
# ValueError: tuple.index(x): x not in tuple

# %%
T=(1,2,3,4,5,6,6,6,6)
T.count(6)
# Out:
# 4

# %%
s="pyth"
print(id(s))

s=s+"3"
print(id(s))
print(s)
# Out:
# 134579542179536
# 134579542179488
# pyth3

# %%
s[0]="j"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-279305434.py in <cell line: 0>()
# ----> 1 s[0]="j"
#
# TypeError: 'str' object does not support item assignment

# %%
x=  10
y=x
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664

# %%
t1=(4,7,6)
t2=t1
print(id(t1))
print(id(t2))
# Out:
# 134579951677440
# 134579951677440

# %%
a='Gkvk'
print(id(a))
a=a+"University"
print(id(a))
# Out:
# 136396945563760
# 136396945953072

# %%
s='Python'
print(id(s))
s=s+'3'
print(s)
print(id(s))
s="python"
s[0]='J'
# Out:
# 10694112
# Python3
# 136396945565008
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12140/432241090.py in <cell line: 0>()
#       5 print(id(s))
#       6 s="python"
# ----> 7 s[0]='J'
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x)) #Integers are also immutable
print(id(y))
x=x+20
print(id(x))
print(id(y))
# Out:
# 11645640
# 11645640
# 11646280
# 11645640

# %%
L1=[1,2,3,4]
L2=L1
print(id(L1))
print(id(L2))
# Out:
# 136396945434368
# 136396945434368
