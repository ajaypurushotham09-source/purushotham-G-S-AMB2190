# %%
#PURUSHOTHAM GS

# %%
file = open("gkvk.txt","w")
file.write("hello world")
file.close()

# %%
file = open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello world

# %%
file = open("gkvk.txt","a")
file.write("\nhi")
file.close()

# %%
file = open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello worldhihi
# hi

# %%
file = open("pavan.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2013124868.py in <cell line: 0>()
# ----> 1 file = open("pavan.txt","r")
#       2 content=file.read()
#       3 print(content)
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pavan.txt'

# %%
file = open("gkvk.txt","r")
content=file.readlines()
print(content)
file.close()
# Out:
# ['hello worldhihi\n', 'hi']

# %%
with open("gkvk.txt","r") as file:
    print(file.read())
# Out:
# hello worldhihi
# hi

# %%
#exceptional handling wiyh files
try:
  file = open("xyz.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("file not found")
# Out:
# file not found

# %%
try:
  file = open("gkvk.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("file not found")
# Out:
# hello worldhihi
# hi

# %%
try:
  with open("gkvk.txt","r") as f:
    line=f.read()
    print(line)
except:
  print("file not found")
# Out:
# hello worldhihi
# hi

# %%
try:
  with open("abc.txt","r") as f:
    line=f.read()
    print(line)
except:
  print("file not found")
# Out:
# file not found

# %%
def div(a,b):
  c=a/b
  print(c)

a=3
b=5
div(a,b)
# Out:
# 0.6

# %%
def div(a,b):
  try:
    c=a/b
    print(c)
  except ZeroDivisionError:
    print("divided by zero")
  except TypeError:
    print("invalid input")
  except NameError:
    print("variable not defined")
  except:
    print("some error")
  else:
    print("no error")
    print("value of c",c)
  finally:
    print("end of program")

a=int(input("enter a number"))
b=int(input("enter a number"))
div(a,b)
# Out:
# enter a number2
# enter a number0
# divided by zero
# end of program

# %%
import random

# Initialize inventory and money 🎒💰
inventory = {}
total_money = 0

# Fish types and prices 🐟
fish_prices = {
   "Rohu": 12,
    "Catla": 18,
    "Sinchu": 25
}

def showmenu():
 print("\n🎣 --- ಏನ್ ಮಾಡತಿಯೋ  --- 🎣")
 print("1️⃣ ಮೀನನ್ನು ಹಿಡಿ ")
 print("2️⃣ ನೀನು ಹಿಡಿದಿರೋದೇ ಇಷ್ಟು ")
 print("3️⃣ ಮಾರೋ ")
 print("4️⃣ ಹೋಗು   🚪")

showmenu()

# Game loop 🔁
while True:
    choice = int(input("ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : "))

    # Catch Fish 🐠
    if choice == 1:
        fish = random.choice(list(fish_prices.keys()))
        inventory[fish] = inventory.get(fish, 0) + 1
        print(f"🎉 ನೀನು ಹಿಡಿದಿದ್ದು  {fish}!")

    # View Inventory 🎒
    elif choice == 2:
        if inventory == {}:       #if len(inventory) == 0:      #if not inventory:
            print("❌ ಮೊದಲು ಮೀನು ಹಿಡಿ .")
        else:
            print("📦  ನೀನು ಹಿಡಿದಿರೋದೇ ಇಷ್ಟು:")
            for fish, count in inventory.items():
                print(f"{fish}: {count}")

    # Sell Fish 💵
    elif choice == 3:
        if inventory == {}:
            print("❌ ಮೀನೇ ಇಲ್ಲ ಕಣೋ ಮಾರೋಕೆ .")
        else:
            earnings = 0
            for fish, count in inventory.items():
                earnings += fish_prices[fish] * count
            total_money += earnings  # total_money = total_money earnings
            inventory.clear()
            print(f"💰ನೀನು ಮಾರಿದ್ದು  ${earnings}!")

    # Exit 🚪
    elif choice == 4:
        print(f"🏁 ಇಷ್ಟೇ ನೀನು ದೂಡಿದಿರೋದು : ${total_money}")
        print("👋  ಹೋಗು ")
        break

    else:
        print("⚠️ Try again.")
# Out:
# 🎣 --- ಏನ್ ಮಾಡತಿಯೋ  --- 🎣
# 1️⃣ ಮೀನನ್ನು ಹಿಡಿ
# 2️⃣ ನೀನು ಹಿಡಿದಿರೋದೇ ಇಷ್ಟು
# 3️⃣ ಮಾರೋ
# 4️⃣ ಹೋಗು   🚪
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Sinchu!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Rohu!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Catla!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Catla!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Sinchu!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Rohu!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Catla!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 1
# 🎉 ನೀನು ಹಿಡಿದಿದ್ದು  Catla!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 2
# 📦  ನೀನು ಹಿಡಿದಿರೋದೇ ಇಷ್ಟು:
# Sinchu: 2
# Rohu: 2
# Catla: 4
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 3
# 💰ನೀನು ಮಾರಿದ್ದು  $146!
# ಯೇನದರೂ ಚೂಸ್ ಮಾಡು : 4
# 🏁 ಇಷ್ಟೇ ನೀನು ದೂಡಿದಿರೋದು : $146
# 👋  ಹೋಗು

# %%
import random

# Initialize inventory and money 🎒💰
inventory = {}
total_money = 0

# Fish types and prices 🐟
fish_prices = {
   "Rohu": 12,
    "Catla": 18,
    "Sinchu": 25
}

def showmenu():

 print("\n🎣 --- Fishing Game Menu --- 🎣")
 print("1️⃣ Catch Fish")
 print("2️⃣ View Inventory")
 print("3️⃣ Sell Fish")
 print("4️⃣ Exit 🚪")

showmenu()

# Game loop 🔁
while True:
    choice = int(input("Choose an option: "))

    # Catch Fish 🐠
    if choice == 1:
        fish = random.choice(list(fish_prices.keys()))
        inventory[fish] = inventory.get(fish, 0) + 1
        print(f"🎉 You caught a {fish}!")

    # View Inventory 🎒
    elif choice == 2:
        if inventory == {}:       #if len(inventory) == 0:      #if not inventory:
            print("❌ No fish.")
        else:
            print("📦 Your Inventory:")
            for fish, count in inventory.items():
                print(f"{fish}: {count}")

    # Sell Fish 💵
    elif choice == 3:
        if inventory == {}:
            print("❌ No fish to sell.")
        else:
            earnings = 0
            for fish, count in inventory.items():
                earnings += fish_prices[fish] * count
            total_money += earnings  # total_money = total_money earnings
            inventory.clear()
            print(f"💰 You sold all fish for ${earnings}!")

    # Exit 🚪
    elif choice == 4:
        print(f"🏁 Final money earned: ${total_money}")
        print("👋 Thanks for playing!")
        break

    else:
        print("⚠️ Invalid choice. Try again.")
# Out:
# 🎣 --- Fishing Game Menu --- 🎣
# 1️⃣ Catch Fish
# 2️⃣ View Inventory
# 3️⃣ Sell Fish
# 4️⃣ Exit 🚪
# Choose an option: 4
# 🏁 Final money earned: $0
# 👋 Thanks for playing!

# %%
import random

# Initialize inventory and money 🎒💰
inventory = {}
total_money = 0

# Fish types and prices 🐟
fish_prices = {
   "Rohu": 12,
    "Catla": 18,
    "Sinchu": 25
}

def showmenu():

 print("\n🎣 --- Fishing Game Menu --- 🎣")
 print("1️⃣ Catch Fish")
 print("2️⃣ View Inventory")
 print("3️⃣ Sell Fish")
 print("4️⃣ Exit 🚪")

showmenu()

def choice1():
  fish = random.choice(list(fish_prices.keys()))
  inventory[fish] = inventory.get(fish, 0) + 1
  print(f"🎉 You caught a {fish}!")

def choice2():
   if inventory == {}:       #if len(inventory) == 0:      #if not inventory:
      print("❌ No fish.")
   else:
      print("📦 Your Inventory:")
      for fish, count in inventory.items():
       print(f"{fish}: {count}")

def choice3():
  global total_money
  if inventory == {}:
    print("❌ No fish to sell.")
  else:
    earnings = 0
    for fish, count in inventory.items():
                earnings += fish_prices[fish] * count
    total_money += earnings  # total_money = total_money earnings
    inventory.clear()
    print(f"💰 You sold all fish for ${earnings}!")


def choice4():
  print(f"🏁 Final money earned: ${total_money}")
  print("👋 Thanks for playing!")



# Game loop 🔁
while True:
    choice = int(input("Choose an option: "))

    # Catch Fish 🐠
    if choice == 1:
        choice1()

    # View Inventory 🎒
    elif choice == 2:
        choice2()

    # Sell Fish 💵
    elif choice == 3:
       choice3()

    # Exit 🚪
    elif choice == 4:
       choice4()
       break

    else:
        print("⚠️ Invalid choice. Try again.")
# Out:
# 🎣 --- Fishing Game Menu --- 🎣
# 1️⃣ Catch Fish
# 2️⃣ View Inventory
# 3️⃣ Sell Fish
# 4️⃣ Exit 🚪
# Choose an option: 1
# 🎉 You caught a Rohu!
# Choose an option: 2
# 📦 Your Inventory:
# Rohu: 1
# Choose an option: 3
# 💰 You sold all fish for $12!
# Choose an option: 4
# 🏁 Final money earned: $12
# 👋 Thanks for playing!
