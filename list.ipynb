# %%
#PURUSHOTHAM GS

# %% [markdown]
# 29/12/25 - Monday

# %%
ph=float(input("enter the ph of the soil "))
print("ph of the soil is {}".format(ph))
if ph<5.5:
  print("soil is acidic")
elif ph<=7.5:
  print("soil is neutral")
elif ph>=8.5:
  print("soil is alkaline")
else:
  print("highly alkaline")
# Out:
# enter the ph of the soil 5
# ph of the soil is 5.0
# soil is acidic

# %%
x=[23,56,58] #Membership operators
print(23 in x)
print(78 in x)
# Out:
# True
# False

# %%
x=[45,67,98] #Membership operators
print(45 not in x)
print(46 not in x)
# Out:
# False
# True

# %%
print(x)
for i in x:
  print("value of ",i)
# Out:
# [45, 67, 98]
# value of  45
# value of  67
# value of  98

# %%
print(x)
for i in x:
  print("value of {} after adding 3 is {}".format(i,i+3))
# Out:
# [45, 67, 98]
# value of 45 after adding 3 is 48
# value of 67 after adding 3 is 70
# value of 98 after adding 3 is 101

# %%
x=[12,34,52]
if 10 not in x: #if true
  print("mark absent for 10")
if 12 in x: #if true
  print('mark present for 12 ')
print('end')
# Out:
# mark absent for 10
# mark present for 12
# end

# %%
#list of crops
crops=['rice','wheat','maize']
#dispaly crops
print("crops grown in field are")
for i in crops:
  print(i)
# Out:
# crops grown in field are
# rice
# wheat
# maize

# %%
crops=['rice','wheat','maize']
crops.append('sugarcane')
print(crops)
# Out:
# ['rice', 'wheat', 'maize', 'sugarcane']

# %%
print('number of crops grown are',len(crops))
# Out:
# number of crops grown are 4

# %%
print ('maize' in crops)
# Out:
# True

# %%
if "maize" in crops:
  print("maize is present in the list")
if "onion" in crops:
  print("onion is present in the list")
else:
  print("onion is not grown")
# Out:
# maize is present in the list
# onion is not grown

# %%
print(crops.pop(1))
print(len(crops))
# Out:
# wheat
# 3

# %%
#find the index of crop
crops=['rice','wheat','maize']
crops.index('wheat')
print('wheat is at index',index_wheat)
print(crops.index('wheat'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4085812850.py in <cell line: 0>()
#       2 crops=['rice','wheat','maize']
#       3 crops.index('wheat')
# ----> 4 print('wheat is at index',index_wheat)
#       5 print(crops.index('wheat'))
#
# NameError: name 'index_wheat' is not defined

# %%
crops.insert(1,'sugarcane')
print("after inserting sugarcane")
print(crops)
# Out:
# after inserting sugarcane
# ['rice', 'sugarcane', 'wheat', 'maize']

# %%
crops=['rice', 'sugarcane', 'wheat', 'maize']
crops.pop() #remove last crop
print('after removing last crop')
print(crops)
# Out:
# after removing last crop
# ['rice', 'sugarcane', 'wheat']

# %%
soilmoisture=[45,60,30,55,40]
for i in soilmoisture:
 print('soil moisture is {}%'.format(i))
# Out:
# soil moisture is 45%
# soil moisture is 60%
# soil moisture is 30%
# soil moisture is 55%
# soil moisture is 40%

# %%
for i in soilmoisture:
  if i<50:
     print('irrigation needed')
  else:
    print("sufficient moisture")
# Out:
# irrigation needed
# sufficient moisture
# irrigation needed
# sufficient moisture
# irrigation needed

# %%
print(len(soilmoisture))
# Out:
# 5

# %%
soilmoisture=[45,60,30,55,40]
soilmoisture.append(65)
print(soilmoisture)
# Out:
# [45, 60, 30, 55, 40, 65]

# %%
soilmoisture=[45,60,30,55,40,65]
soilmoisture.pop(2)
print(soilmoisture)
print(soilmoisture.count(30))
# Out:
# [45, 60, 55, 40, 65]
# 0

# %%
soilmoisture.sort()
print(soilmoisture)
# Out:
# [40, 45, 55, 60, 65]

# %%
soilmoisture=[45,60,30,55,40,65]
print(max(soilmoisture))
print(min(soilmoisture))
# Out:
# 65
# 30

# %% [markdown]
# 30/12/25 - Tuesday

# %%
names=['pavan','pavan kengeri','pavan shivamogga']
age=[50,23,21]
for i in range(len(names)):
 print(names[i], "age is",age[i])
# Out:
# pavan age is 50
# pavan kengeri age is 23
# pavan shivamogga age is 21

# %%
names=['pavan','pavan kengeri','pavan shivamogga']
age=[50,23,21]
for n,a in zip (names,age):
  print(n,"age is",a)
# Out:
# pavan age is 50
# pavan kengeri age is 23
# pavan shivamogga age is 21

# %%
crops=['sugarcane','rice','maize','millets','pulses']
water_requirement=[2000,1200,800,500,350]
print(len(crops))
print(range(len(crops)))

print('crop water requirement is:')
for i in range(len(crops)):
  print(crops[i],water_requirement[i],"mm")
# Out:
# 5
# range(0, 5)
# crop water requirement is:
# sugarcane 2000 mm
# rice 1200 mm
# maize 800 mm
# millets 500 mm
# pulses 350 mm

# %%
print('crop water requirement is:')
for c,w in zip (crops,water_requirement):
 print(c,w,"mm")
# Out:
# crop water requirement is:
# sugarcane 2000 mm
# rice 1200 mm
# maize 800 mm
# millets 500 mm
# pulses 350 mm

# %%
print('crops which have (>580 mm) water requirement:')
for i in range(len(water_requirement)):
  if water_requirement [i]>580:
    print(crops[i])
# Out:
# crops which have (>580 mm) water requirement:
# sugarcane
# rice
# maize

# %%
print('crops which have (>580 mm) water requirement:')
for c,w in zip (crops,water_requirement):
  if (w)>580:
    print(c)
# Out:
# crops which have (>580 mm) water requirement:
# sugarcane
# rice
# maize

# %%
yield_tons=[150,30,40,15,8]
average_yield=sum(yield_tons)/len(yield_tons)
print('average yield is',average_yield)
# Out:
# average yield is 48.6

# %%
max_water = max(water_requirement)
print(max_water)
index = water_requirement.index(max_water)
print("crop with highest water requirement is:",crops[index])
# Out:
# 2000
# crop with highest water requirement is: sugarcane

# %%
max_crop =max(zip(water_requirement,crops))
print(max_crop)
print("crop with highest water requirement is:",max_crop[1])
# Out:
# (2000, 'sugarcane')
# crop with highest water requirement is: sugarcane

# %%
max_crop=max(yield_tons)
print(max_crop)
inedx=yield_tons.index(max_crop)
print("crop with highest yield is:",crops[index])
# Out:
# 150
# crop with highest yield is: sugarcane

# %%
max_crop=max(zip(yield_tons,crops))
print(max_crop)
print("crop with highest yield is:",max_crop[1])
# Out:
# (150, 'sugarcane')
# crop with highest yield is: sugarcane

# %%
average_yield=sum(yield_tons)/len(yield_tons)
print("high yeilding crops are:")
for i in range(len(crops)):
  if yield_tons[i]>average_yield:
    print(crops[i])
# Out:
# high yeilding crops are:
# sugarcane

# %%
average_yield=sum(yield_tons)/len(yield_tons)
print("high yeilding crops are:")
for c,y in zip(crops,yield_tons):
  if y>average_yield:
    print(c)
# Out:
# high yeilding crops are:
# sugarcane

# %%
crops=['rice','wheat','maize','pulses']
fertilizer=['urea','dap','npk','compost']
for i in range(len(crops)):
  print(crops[i],"required fertilizer is",fertilizer[i])
# Out:
# rice required fertilizer is urea
# wheat required fertilizer is dap
# maize required fertilizer is npk
# pulses required fertilizer is compost

# %%
for c,f in zip(crops,fertilizer):
  print(c,"required fertilizer is",f)
# Out:
# rice required fertilizer is urea
# wheat required fertilizer is dap
# maize required fertilizer is npk
# pulses required fertilizer is compost

# %% [markdown]
# 31/12/25 - wednesday

# %%
pesticides = ["NeemOil", "Chlorpyrifos", "Malathion", "Imidacloprid", "Spinosad"]
effectiveness = [75, 85, 70, 90, 88]
max_effective=max(effectiveness)
print(max_effective)
print("the most effective pesticide is ",pesticides[effectiveness.index(max_effective)])
# Out:
# 90
# the most effective pesticide is  Imidacloprid

# %%
min_effective=min(effectiveness)
print(min_effective)
print("the least effective pesticide is ",pesticides[effectiveness.index(min_effective)])
# Out:
# 70
# the least effective pesticide is  Malathion

# %%
avg_effectiveness=sum(effectiveness)/len(effectiveness)
print("average effectiveness is",avg_effectiveness)
# Out:
# average effectiveness is 81.6

# %%
print("the most effective pesticides are ")
for i in range(len(pesticides)):
 if effectiveness[i]>avg_effectiveness:
   print(pesticides[i])
# Out:
# the most effective pesticides are
# Chlorpyrifos
# Imidacloprid
# Spinosad

# %%
print("the most effective pesticides are ")
for p,e in zip(pesticides,effectiveness):
 if e>avg_effectiveness:
   print(p)
# Out:
# the most effective pesticides are
# Chlorpyrifos
# Imidacloprid
# Spinosad

# %%
print("the pesticides whoose effectiveness is above 80% is")
for i in range(len(pesticides)):
 if effectiveness[i]>80:
   print(pesticides[i])
# Out:
# the pesticides whoose effectiveness is above 80% is
# Chlorpyrifos
# Imidacloprid
# Spinosad

# %%
print("the pesticides whoose effectiveness is above 80% is")
for p,e in zip(pesticides,effectiveness):
  if e>80:
    print(p)
# Out:
# the pesticides whoose effectiveness is above 80% is
# Chlorpyrifos
# Imidacloprid
# Spinosad

# %%
print("number of pesticides whoose effectiveness is below 80% is")
below_80=[]
for i in range(len(effectiveness)):
 if effectiveness[i]>80:
  print((effectiveness[i]))
# Out:
# number of pesticides whoose effectiveness is below 80% is
# 85
# 90
# 88

# %%
print("number of pesticides whoose effectiveness is below 80% is")
count=0
for i in range(len(effectiveness)):
  if effectiveness[i]<80:
    count=count+1
print(count)
# Out:
# number of pesticides whoose effectiveness is below 80% is
# 2

# %%
count1=0
for e,c in zip(effectiveness,pesticides):
  if e<80:
    count1=count1+1
print("number of pesticides whoose effectiveness is below 80% is",count1)
# Out:
# number of pesticides whoose effectiveness is below 80% is 2

# %%
print('icreased effectiveness by 5% ')
for i in range(len(effectiveness)):
 print((effectiveness[i]+5))
print(effectiveness)
# Out:
# icreased effectiveness by 5%
# 80
# 90
# 75
# 95
# 93
# [75, 85, 70, 90, 88]

# %%
print('icreased effectiveness by 5% ')
for p,e in zip(pesticides,effectiveness):
 print(e+5)
print(effectiveness)
# Out:
# icreased effectiveness by 5%
# 80
# 90
# 75
# 95
# 93
# [75, 85, 70, 90, 88]

# %%
print("the pesticides suitable for organic farming(>=85%) is")
for i in range(len(pesticides)):
 if effectiveness[i]>=85:
   print(pesticides[i])
# Out:
# the pesticides suitable for organic farming(>=85%) is
# Chlorpyrifos
# Imidacloprid
# Spinosad

# %%
print("the pesticides suitable for organic farming(>=85%) is")
for p,e in zip(pesticides,effectiveness):
  if e>=85:
    print(p)
# Out:
# the pesticides suitable for organic farming(>=85%) is
# Chlorpyrifos
# Imidacloprid
# Spinosad

# %%
effectiveness.sort()
print(effectiveness)
# Out:
# [70, 75, 85, 88, 90]

# %% [markdown]
# 2)	Farm Equipment Cost

# %%
equipment = ["Tractor", "Plough", "Harvester", "Seeder", "Sprayer", "Thresher"]
cost = [850000, 25000, 1200000, 60000, 18000, 95000]
most_expensive=max(cost)
print(most_expensive)
print("the most expensive equipment is ",equipment[cost.index(most_expensive)])
# Out:
# 1200000
# the most expensive equipment is  Harvester

# %%
min_expensive=min(cost)
print(min_expensive)
print("the least expensive equipment is ",equipment[cost.index(min_expensive)])
# Out:
# 18000
# the least expensive equipment is  Sprayer

# %%
difference_in_cost=max(cost)-min(cost)
print("the difference between the most and least expensive equipment is",difference_in_cost)
# Out:
# the difference between the most and least expensive equipment is 1182000

# %%
avg_cost=sum(cost)/len(cost)
print(avg_cost)
# Out:
# 374666.6666666667

# %%
for i in range(len(equipment)):
  if cost[i]==avg_cost:
    print(cost[i])

# %%
for i in range(len(equipment)):
  if cost[i]>=avg_cost:
    print(cost[i])
# Out:
# 850000
# 1200000

# %%
for i in range(len(equipment)):
  if cost[i]<=100000:
    print(equipment[i] ,cost[i],"-eligible")
# Out:
# Plough 25000 -eligible
# Seeder 60000 -eligible
# Sprayer 18000 -eligible
# Thresher 95000 -eligible

# %%
for i in range(len(equipment)):
  if cost[i]>=500000:
    print(equipment[i],cost[i],"eligible for loan")
# Out:
# Tractor 850000 eligible for loan
# Harvester 1200000 eligible for loan

# %%
print("suitable for small scale farmers" )
for i in range(len(equipment)):
  if cost[i]<75000:
    print(equipment[i])
# Out:
# suitable for small scale farmers
# Plough
# Seeder
# Sprayer

# %%
cost = [850000, 25000, 1200000, 60000, 18000, 95000]
print(cost)
n_cost=cost.copy()
print(n_cost)
n_cost.sort()
print(n_cost)
# Out:
# [850000, 25000, 1200000, 60000, 18000, 95000]
# [850000, 25000, 1200000, 60000, 18000, 95000]
# [18000, 25000, 60000, 95000, 850000, 1200000]

# %%
for i in range(len(equipment)):
  if cost[i]>50000 and cost[i]<100000:
    print(equipment[i])
# Out:
# Harvester
# Seeder

# %% [markdown]
# 1/1/26 - Thursday

# %%
list=[34,56,52,67,89]
list[2:4]
# Out:
# [52, 67]

# %%
list[3:9]
# Out:
# [67, 89]

# %%
list[:5]
# Out:
# [34, 56, 52, 67, 89]

# %%
list[1:]
# Out:
# [56, 52, 67, 89]

# %%
list[-3:-1]
# Out:
# [52, 67]

# %%
list[-4:-5]
# Out:
# []

# %%
list[6:4]
# Out:
# []

# %%
print(list[1:5:2])
print(list[1:5:1])
print(list[1:5:])
# Out:
# [56, 67]
# [56, 52, 67, 89]
# [56, 52, 67, 89]

# %%
crops=['sugarcane','rice','maize','millets','pulses']
print(crops[:3])
print(crops[1:2])
print(crops[-5:-2])
print(crops[-2:])
# Out:
# ['sugarcane', 'rice', 'maize']
# ['rice']
# ['sugarcane', 'rice', 'maize']
# ['millets', 'pulses']

# %%
list=[34,56,52,67,89]
list[4:2:1]
print(list[4:2:-1])
list[-4:-2:1]
list[-2:-4:-1]
# Out:
# [89, 67]
# [67, 52]

# %%
print(crops[::-1])
# Out:
# ['pulses', 'millets', 'maize', 'rice', 'sugarcane']

# %%
print(list[-2:-4:-1])
print(list[-2:-4:1])
# Out:
# [67, 52]
# []

# %%
crops=["rice","wheat","maize","millet","pulses","cotton"]
print(crops[1:-1])
# Out:
# ['wheat', 'maize', 'millet', 'pulses']

# %%
#create a new list with each element increased by 2
num=[12,14,16,18,20]
new=[]
for i in num:
  new.append(i+2)
print("new list",new)
print("original list",num)
# Out:
# new list [14, 16, 18, 20, 22]
# original list [12, 14, 16, 18, 20]

# %%
num=[12,14,16,18,20]
new=[i+2 for i in num]
print("new list",new)
print("original list",num)
# Out:
# new list [14, 16, 18, 20, 22]
# original list [12, 14, 16, 18, 20]

# %%
num=[12,14,16,18,20]
new=[]
for i in num:
  if i%4==0:
   new.append(i)
print("numbers divisible by 4 are",new)
print("original list",num)
# Out:
# numbers divisible by 4 are [12, 16, 20]
# original list [12, 14, 16, 18, 20]

# %%
num=[12,14,16,18,20]
new=[ i for i in num if i%4==0]
print("numbers divisible by 4 are",new)
print("original list",num)
# Out:
# numbers divisible by 4 are [12, 16, 20]
# original list [12, 14, 16, 18, 20]

# %%
n=[43,56,87,90,54,87]
new=["even" if i%2==0 else "odd" for i in n]
print(new)
# Out:
# ['odd', 'even', 'odd', 'even', 'even', 'odd']

# %% [markdown]
# 2/6/25 - friday

# %%
equipment = ["Tractor", "Plough", "Harvester", "Seeder", "Sprayer", "Thresher"]
cost = [850000, 25000, 1200000, 60000, 18000, 95000]
updated_cost=[]
for y in cost:
  updated_cost.append(y*1.08)
print(updated_cost)
# Out:
# [918000.0000000001, 27000.0, 1296000.0, 64800.00000000001, 19440.0, 102600.0]

# %%
updated_cost=[]
for y in cost:
  updated_cost.append(round((y*1.08),5))
print(updated_cost)
# Out:
# [918000.0, 27000.0, 1296000.0, 64800.0, 19440.0, 102600.0]

# %%
updated_cost=[]
for y in cost:
  updated_cost.append(round(y*1.08))
print(updated_cost)
# Out:
# [918000, 27000, 1296000, 64800, 19440, 102600]

# %%
x=max(zip(equipment,cost))
print( "the maximum cost is",x[1])
# Out:
# the maximum cost is 850000

# %%
max_cost=max(cost)
print("the most expensive equipment is {} {}".format(equipment[cost.index(max_cost)],max_cost))
# Out:
# the most expensive equipment is Harvester 1200000

# %%
equipment_updated=[]
for i in range(len(equipment)):
  if updated_cost[i]>1000000:
    equipment_updated.append("high investment")
  else:
    equipment_updated.append(equipment[i])
print("equipment list after replacement:\n",equipment_updated)
# Out:
# equipment list after replacement:
#  ['Tractor', 'Plough', 'high investment', 'Seeder', 'Sprayer', 'Thresher']

# %%
categories=[]
for c in updated_cost:
  if c>1000000:
    categories.append("high investment")
  elif c>500000:
    categories.append("medium investment")
  else:
    categories.append("low investment")
print("cost categories",categories)
# Out:
# cost categories ['medium investment', 'low investment', 'high investment', 'low investment', 'low investment', 'low investment']

# %%
subsidy_cost=[]
for c in cost:
  if c<100000:
    subsidy_cost.append(int(c*0.85))
  else:
    subsidy_cost.append(c)
print("subsidy cost",subsidy_cost)
# Out:
# subsidy cost [850000, 21250, 1200000, 51000, 15300, 80750]

# %%
print(bool(True))
# Out:
# True

# %%
print(bool(False))
# Out:
# False

# %%
i=1
while(i<=20):
    if i%3==0:
        print(i)
    i+=1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
